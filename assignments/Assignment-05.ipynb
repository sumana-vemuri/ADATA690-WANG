# %% [markdown]
# ### Assignment 5
#
# You will unzip the zip file manually in preparation for this assignment.
#
# The link to the zip file is (you have already used it in your assignment 3):
#
# https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
#
# After unzipping, You will have all files in one folder named "CollegeScorecard_Raw_Data"
#
# The folder contains the yearly data files from 1996 to 2017 school years.
#
# Your Jupyter Notebook file should not be in the CollegeScorecard_Raw_Data folder.
#
# I suggest you create a new folder call "Assignment4" and place the Notebook file and the data folder under it.
#
# Assignment4/
#     - Jay.ipynb
#     - CollegeScorecard_Raw_Data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'

# %%
# <1> 
# Import libraries
import os
import matplotlib.pyplot as plt
#(Write code here)

# %%
# <2>
# Find out what files are in the folder and assign the list of files to a variable for later processing
# you would need to import a library call os which stands for operating system. so place that import statement in previous cell.
# # os library also has method getcwd() to get the current working directory. since your notebook and your data files are not in 
# the same folder, you want to make sure what is the current working folder and how to access a data file in a different folder
# display the current workin directory
#(Write code here)


os.getcwd()
# Out:
# 'C:\\Users\\SUMANA\\Downloads'

# %%
# <3> 
# os library has a method call listdir which generates a list of files in a directory/folder
# use this method to assign the contents of the data folder to a variable and display it
#(Write code here)
DATA_FOLDER="CollegeScorecard_Raw_Data"
file_names=os.listdir(DATA_FOLDER)
#C:\Users\SUMANA\Downloads\CollegeScorecard_Raw_Data
file_names
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'Crosswalks.zip',
#  'data.yaml',
#  'FieldOfStudyData1415_1516_PP.csv',
#  'FieldOfStudyData1516_1617_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv']

# %%
# <4> 
# The folder contains a couple of files that are not the yearly data files
# write code to remove the unwanted files from the list (Note: not from the folder in your drive)
# hint: use pop or remove functions of a list. pop and remove work differently though.
#(Write code here)

#csv_files=[]
#for name in file_names:
#    if name.endswith('.csv'):
#        csv_files.append(name)

csv_files=[name for name in file_names if name.startswith('MERGED')]
csv_files
# Out:
# ['MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv']

# %%
filename='MERGED2016_17_PP.csv'
filename[6:10]
# Out:
# '2016'

# %%
# <5> 
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load three columns: UNITID, ADM_RATE, and TUITIONFEE_IN
# You also want to add a new column call "YEAR" to differentiate the data frames from each other.
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a 
# new single data frame.
# Note: this exercise incorporates many techques we learned before
# - list (creating an empty, append an item to the list)
# - for loop 
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
# This exercise may appear a big challenging but it worths the effort. You will learn a lot and  love it. I promise.

#(Write code here)
import pandas as pd
#df1=pd.read_csv("")
df_list=[]

for csv_file in csv_files:
    df=pd.read_csv(DATA_FOLDER + "/"+ csv_file ,usecols=["UNITID","INSTNM","ADM_RATE","TUITIONFEE_IN"])
    df['year']=csv_file[6:10]
    df_list.append(df)
    
    print("processing file:", csv_file)
df_list
# Out:
# processing file: MERGED1996_97_PP.csv
# processing file: MERGED1997_98_PP.csv
# processing file: MERGED1998_99_PP.csv
# processing file: MERGED1999_00_PP.csv
# processing file: MERGED2000_01_PP.csv
# processing file: MERGED2001_02_PP.csv
# processing file: MERGED2002_03_PP.csv
# processing file: MERGED2003_04_PP.csv
# processing file: MERGED2004_05_PP.csv
# processing file: MERGED2005_06_PP.csv
# processing file: MERGED2006_07_PP.csv
# processing file: MERGED2007_08_PP.csv
# processing file: MERGED2008_09_PP.csv
# processing file: MERGED2009_10_PP.csv
# processing file: MERGED2010_11_PP.csv
# processing file: MERGED2011_12_PP.csv
# processing file: MERGED2012_13_PP.csv
# processing file: MERGED2013_14_PP.csv
# processing file: MERGED2014_15_PP.csv
# processing file: MERGED2015_16_PP.csv
# processing file: MERGED2016_17_PP.csv
# processing file: MERGED2017_18_PP.csv
# [      UNITID                                           INSTNM  ADM_RATE  \
#  0     100636               Community College of the Air Force       NaN
#  1     100654                         Alabama A & M University       NaN
#  2     100663              University of Alabama at Birmingham       NaN
#  3     100672           ALABAMA AVIATION AND TECHNICAL COLLEGE       NaN
#  4     100690                               Amridge University       NaN
#  ...      ...                                              ...       ...
#  6789  428347  American Institute of Medical-Dental Technology       NaN
#  6790  428365          INSTITUTO DE ESTETICA Y BELLAZA MARUGIE       NaN
#  6791  428374                           KEISER COLLEGE-DAYTONA       NaN
#  6792  428392                        Klamath Community College       NaN
#  6793  428444                     The Art Institute of Phoenix       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  1996
#  1               NaN  1996
#  2               NaN  1996
#  3               NaN  1996
#  4               NaN  1996
#  ...             ...   ...
#  6789            NaN  1996
#  6790            NaN  1996
#  6791            NaN  1996
#  6792            NaN  1996
#  6793            NaN  1996
#
#  [6794 rows x 5 columns],
#        UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100636      Community College of the Air Force       NaN            NaN
#  1     100654                Alabama A & M University       NaN            NaN
#  2     100663     University of Alabama at Birmingham       NaN            NaN
#  3     100672  ALABAMA AVIATION AND TECHNICAL COLLEGE       NaN            NaN
#  4     100690                      Amridge University       NaN            NaN
#  ...      ...                                     ...       ...            ...
#  6694  432418                 MANHATTAN BEAUTY SCHOOL       NaN            NaN
#  6695  432436                 COOPER CAREER INSTITUTE       NaN            NaN
#  6696  432445            OCCUPATIONAL TRAINING CENTER       NaN            NaN
#  6697  432472  ABC SPA CITY BEAUTY AND BARBER COLLEGE       NaN            NaN
#  6698  432524      Delaware College of Art and Design       NaN            NaN
#
#        year
#  0     1997
#  1     1997
#  2     1997
#  3     1997
#  4     1997
#  ...    ...
#  6694  1997
#  6695  1997
#  6696  1997
#  6697  1997
#  6698  1997
#
#  [6699 rows x 5 columns],
#        UNITID                                       INSTNM  ADM_RATE  \
#  0     100654                     Alabama A & M University       NaN
#  1     100663          University of Alabama at Birmingham       NaN
#  2     100690                           Amridge University       NaN
#  3     100706          University of Alabama in Huntsville       NaN
#  4     100724                     Alabama State University       NaN
#  ...      ...                                          ...       ...
#  6475  434779                  WATERMAN TRAINING INSTITUTE       NaN
#  6476  434849                                CSC Institute       NaN
#  6477  434867    CENTER FOR EMPLOYMENT TRAINING-SANTA ROSA       NaN
#  6478  434876  CENTER FOR EMPLOYMENT TRAINING-TRACY CAMPUS       NaN
#  6479  434900                    Dewey University-Carolina       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  1998
#  1               NaN  1998
#  2               NaN  1998
#  3               NaN  1998
#  4               NaN  1998
#  ...             ...   ...
#  6475            NaN  1998
#  6476            NaN  1998
#  6477            NaN  1998
#  6478            NaN  1998
#  6479            NaN  1998
#
#  [6480 rows x 5 columns],
#        UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100654                Alabama A & M University       NaN            NaN
#  1     100663     University of Alabama at Birmingham       NaN            NaN
#  2     100690                      Amridge University       NaN            NaN
#  3     100706     University of Alabama in Huntsville       NaN            NaN
#  4     100724                Alabama State University       NaN            NaN
#  ...      ...                                     ...       ...            ...
#  6461  436784  Universal Career Community College Inc       NaN            NaN
#  6462  436809                       Willsey Institute       NaN            NaN
#  6463  437042      ITT Technical Institute-Saint Rose       NaN            NaN
#  6464  437413              EURO HAIR DESIGN INSTITUTE       NaN            NaN
#  6465  437431          BUCKS COUNTY COMMUNITY COLLEGE       NaN            NaN
#
#        year
#  0     1999
#  1     1999
#  2     1999
#  3     1999
#  4     1999
#  ...    ...
#  6461  1999
#  6462  1999
#  6463  1999
#  6464  1999
#  6465  1999
#
#  [6466 rows x 5 columns],
#        UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100654                Alabama A & M University       NaN         4664.0
#  1     100663     University of Alabama at Birmingham       NaN         3363.0
#  2     100690                      Amridge University       NaN            NaN
#  3     100706     University of Alabama in Huntsville       NaN         3112.0
#  4     100724                Alabama State University       NaN         2520.0
#  ...      ...                                     ...       ...            ...
#  6473  438966             Harrison College-Fort Wayne       NaN         6930.0
#  6474  439039      Lincoln Technical Institute-Hamden       NaN            NaN
#  6475  439109  STRAYER UNIVERSITY-CHESTERFIELD CAMPUS       NaN         8505.0
#  6476  439118              Carrington College-Spokane       NaN            NaN
#  6477  439260    KELLER GRADUATE SCHOOL OF MANAGEMENT       NaN            NaN
#
#        year
#  0     2000
#  1     2000
#  2     2000
#  3     2000
#  4     2000
#  ...    ...
#  6473  2000
#  6474  2000
#  6475  2000
#  6476  2000
#  6477  2000
#
#  [6478 rows x 5 columns],
#        UNITID                               INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100654             Alabama A & M University    0.7505         4664.0
#  1     100663  University of Alabama at Birmingham    0.9098         3640.0
#  2     100690                   Amridge University       NaN            NaN
#  3     100706  University of Alabama in Huntsville    0.8381         3536.0
#  4     100724             Alabama State University       NaN         2904.0
#  ...      ...                                  ...       ...            ...
#  6614  440855             Milan Institute-Amarillo    1.0000            NaN
#  6615  440864                      Trinity College    1.0000            NaN
#  6616  440873           Vatterott College-Dividend    0.9091         7520.0
#  6617  440882              Vatterott College-Tulsa    0.9106         6715.0
#  6618  440891            Vatterott College-Wichita    0.8654         8380.0
#
#        year
#  0     2001
#  1     2001
#  2     2001
#  3     2001
#  4     2001
#  ...    ...
#  6614  2001
#  6615  2001
#  6616  2001
#  6617  2001
#  6618  2001
#
#  [6619 rows x 5 columns],
#        UNITID                                             INSTNM  ADM_RATE  \
#  0     100654                           Alabama A & M University    0.5575
#  1     100663                University of Alabama at Birmingham    0.9117
#  2     100690                                 Amridge University       NaN
#  3     100706                University of Alabama in Huntsville    0.9050
#  4     100724                           Alabama State University    0.6931
#  ...      ...                                                ...       ...
#  6541  442444                 San Joaquin Valley College-Ontario       NaN
#  6542  442462                       Anthem Institute-Cherry Hill    0.6650
#  6543  442499                          Westwood College-Ft Worth    0.7727
#  6544  442505                            Westwood College-Dallas       NaN
#  6545  442514  CoxHealth School of Diagnostic Medical Sonography       NaN
#
#        TUITIONFEE_IN  year
#  0            3040.0  2002
#  1            3880.0  2002
#  2            8960.0  2002
#  3            3764.0  2002
#  4            2904.0  2002
#  ...             ...   ...
#  6541         4925.0  2002
#  6542            NaN  2002
#  6543        10065.0  2002
#  6544        10065.0  2002
#  6545            NaN  2002
#
#  [6546 rows x 5 columns],
#        UNITID                                             INSTNM  ADM_RATE  \
#  0     100654                           Alabama A & M University    0.4457
#  1     100663                University of Alabama at Birmingham    0.8049
#  2     100690                                 Amridge University       NaN
#  3     100706                University of Alabama in Huntsville    0.8756
#  4     100724                           Alabama State University    0.5042
#  ...      ...                                                ...       ...
#  6580  444042             National University College-Rio Grande    0.8782
#  6581  444051  Creative Images Institute of Cosmetology-South...       NaN
#  6582  444060                     Westwood College-Houston South    0.9500
#  6583  444079                      Fortis Institute-Jacksonville       NaN
#  6584  444088                      Brookline College-Albuquerque       NaN
#
#        TUITIONFEE_IN  year
#  0            3352.0  2003
#  1            4274.0  2003
#  2            9440.0  2003
#  3            4126.0  2003
#  4            3600.0  2003
#  ...             ...   ...
#  6580         4480.0  2003
#  6581            NaN  2003
#  6582        10938.0  2003
#  6583            NaN  2003
#  6584            NaN  2003
#
#  [6585 rows x 5 columns],
#          UNITID                               INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0       100654             Alabama A & M University    0.4751         4420.0
#  1       100663  University of Alabama at Birmingham    0.8592         4662.0
#  2       100690                   Amridge University       NaN        10040.0
#  3       100706  University of Alabama in Huntsville    0.8944         4516.0
#  4       100724             Alabama State University    0.5042         4008.0
#  ...        ...                                  ...       ...            ...
#  6655  42171701               SENTINEL CAREER CENTER       NaN            NaN
#  6656  42211801               DE MARGE COLLEGE NORTH       NaN            NaN
#  6657  42312001    Compu-Med Vocational Careers Corp       NaN         4600.0
#  6658  42817001     Southeastern College-Miami Lakes       NaN        11408.0
#  6659  42817002  Southeastern College-St. Petersburg       NaN        11408.0
#
#        year
#  0     2004
#  1     2004
#  2     2004
#  3     2004
#  4     2004
#  ...    ...
#  6655  2004
#  6656  2004
#  6657  2004
#  6658  2004
#  6659  2004
#
#  [6660 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.4199
#  1       100663                University of Alabama at Birmingham    0.8769
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8716
#  4       100724                           Alabama State University    0.5071
#  ...        ...                                                ...       ...
#  6819  43821203             McCann School of Business & Technology       NaN
#  6820  44098901            Texas Barber College - Branch Campus #1       NaN
#  6821  44098902            Texas Barber College - Branch Campus #2       NaN
#  6822  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6823  44098904            Texas Barber College - Branch Campus #5       NaN
#
#        TUITIONFEE_IN  year
#  0            4420.0  2005
#  1            4792.0  2005
#  2           10400.0  2005
#  3            4688.0  2005
#  4            4008.0  2005
#  ...             ...   ...
#  6819         8928.0  2005
#  6820            NaN  2005
#  6821            NaN  2005
#  6822            NaN  2005
#  6823            NaN  2005
#
#  [6824 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.4118
#  1       100663                University of Alabama at Birmingham    0.8778
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8834
#  4       100724                           Alabama State University    0.6698
#  ...        ...                                                ...       ...
#  6843  44098901            Texas Barber College - Branch Campus #1       NaN
#  6844  44098902            Texas Barber College - Branch Campus #2       NaN
#  6845  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6846  44098904            Texas Barber College - Branch Campus #5       NaN
#  6847  44098905  Texas Barber Colleges and Hairstyling Schools ...       NaN
#
#        TUITIONFEE_IN  year
#  0            3640.0  2006
#  1            4792.0  2006
#  2            6000.0  2006
#  3            4848.0  2006
#  4            4008.0  2006
#  ...             ...   ...
#  6843            NaN  2006
#  6844            NaN  2006
#  6845            NaN  2006
#  6846            NaN  2006
#  6847            NaN  2006
#
#  [6848 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.3182
#  1       100663                University of Alabama at Birmingham    0.8778
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8800
#  4       100724                           Alabama State University    0.4159
#  ...        ...                                                ...       ...
#  6885  44098901            Texas Barber College - Branch Campus #1       NaN
#  6886  44098902            Texas Barber College - Branch Campus #2       NaN
#  6887  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6888  44098904            Texas Barber College - Branch Campus #5       NaN
#  6889  44098905  Texas Barber Colleges and Hairstyling Schools ...       NaN
#
#        TUITIONFEE_IN  year
#  0            4072.0  2007
#  1            4208.0  2007
#  2            6240.0  2007
#  3            5216.0  2007
#  4            4508.0  2007
#  ...             ...   ...
#  6885            NaN  2007
#  6886            NaN  2007
#  6887            NaN  2007
#  6888            NaN  2007
#  6889            NaN  2007
#
#  [6890 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.4900
#  1       100663                University of Alabama at Birmingham    0.8510
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8917
#  4       100724                           Alabama State University    0.4228
#  ...        ...                                                ...       ...
#  6970  44098901            Texas Barber College - Branch Campus #1       NaN
#  6971  44098902            Texas Barber College - Branch Campus #2       NaN
#  6972  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6973  44098904            Texas Barber College - Branch Campus #5       NaN
#  6974  44098905  Texas Barber Colleges and Hairstyling Schools ...       NaN
#
#        TUITIONFEE_IN  year
#  0            4072.0  2008
#  1            4664.0  2008
#  2            6600.0  2008
#  3            5952.0  2008
#  4            5460.0  2008
#  ...             ...   ...
#  6970            NaN  2008
#  6971            NaN  2008
#  6972            NaN  2008
#  6973            NaN  2008
#  6974            NaN  2008
#
#  [6975 rows x 5 columns],
#          UNITID                                  INSTNM  ADM_RATE  \
#  0       100654                Alabama A & M University    0.4726
#  1       100663     University of Alabama at Birmingham    0.8357
#  2       100690                      Amridge University    0.8750
#  3       100706     University of Alabama in Huntsville    0.7209
#  4       100724                Alabama State University    0.4625
#  ...        ...                                     ...       ...
#  7144  44326101        Southeastern Institute-Nashville       NaN
#  7145  44936601                       Make-up Designory       NaN
#  7146  44970001   Dayton School of Medical Massage-Lima       NaN
#  7147  44970002    Cincinnati School of Medical Massage       NaN
#  7148  44970003  Cleveland Institute of Medical Massage       NaN
#
#        TUITIONFEE_IN  year
#  0            4692.0  2009
#  1            5096.0  2009
#  2            8000.0  2009
#  3            6510.0  2009
#  4            6468.0  2009
#  ...             ...   ...
#  7144            NaN  2009
#  7145            NaN  2009
#  7146        17300.0  2009
#  7147        17300.0  2009
#  7148        17300.0  2009
#
#  [7149 rows x 5 columns],
#          UNITID                                INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0       100654              Alabama A & M University    0.5129         5800.0
#  1       100663   University of Alabama at Birmingham    0.8243         5806.0
#  2       100690                    Amridge University    0.7143         8360.0
#  3       100706   University of Alabama in Huntsville    0.6614         7492.0
#  4       100724              Alabama State University    0.4372         7164.0
#  ...        ...                                   ...       ...            ...
#  7409  45896402  Strayer University-Charleston Campus       NaN        14085.0
#  7410  45897301             Strayer University-Irving       NaN        14085.0
#  7411  45897302               Strayer University-Katy       NaN        14085.0
#  7412  45897303  Strayer University-Northwest Houston       NaN        14085.0
#  7413  45897304              Strayer University-Plano       NaN        14085.0
#
#        year
#  0     2010
#  1     2010
#  2     2010
#  3     2010
#  4     2010
#  ...    ...
#  7409  2010
#  7410  2010
#  7411  2010
#  7412  2010
#  7413  2010
#
#  [7414 rows x 5 columns],
#          UNITID                                           INSTNM  ADM_RATE  \
#  0       100654                         Alabama A & M University    0.5010
#  1       100663              University of Alabama at Birmingham    0.7223
#  2       100690                               Amridge University       NaN
#  3       100706              University of Alabama in Huntsville    0.6368
#  4       100724                         Alabama State University    0.5080
#  ...        ...                                              ...       ...
#  7670  45920401                                   Unitek College       NaN
#  7671  46163401   Twin Rivers Adult School - Grand Avenue Center       NaN
#  7672  46163402  Twin Rivers Adult School - Arnold Avenue Center       NaN
#  7673  46163403                  Greater Sacramento Urban League       NaN
#  7674  46163404                                            I-TAP       NaN
#
#        TUITIONFEE_IN  year
#  0            6828.0  2011
#  1            6264.0  2011
#  2            8720.0  2011
#  3            8094.0  2011
#  4            8082.0  2011
#  ...             ...   ...
#  7670        17192.0  2011
#  7671            NaN  2011
#  7672            NaN  2011
#  7673            NaN  2011
#  7674            NaN  2011
#
#  [7675 rows x 5 columns],
#          UNITID                                     INSTNM  ADM_RATE  \
#  0       100654                   Alabama A & M University    0.5438
#  1       100663        University of Alabama at Birmingham    0.7223
#  2       100690                         Amridge University       NaN
#  3       100706        University of Alabama in Huntsville    0.7766
#  4       100724                   Alabama State University    0.4604
#  ...        ...                                        ...       ...
#  7788  47691101  SAE Institute of Technology San Francisco       NaN
#  7789  47701101      Strayer University-Bloomington Campus       NaN
#  7790  47702001       Strayer University-Schaumburg Campus       NaN
#  7791  47702002    Strayer University-Downers Grove Campus       NaN
#  7792  47702003           Strayer University-Aurora Campus       NaN
#
#        TUITIONFEE_IN  year
#  0            7182.0  2012
#  1            6798.0  2012
#  2            6800.0  2012
#  3            8794.0  2012
#  4            7932.0  2012
#  ...             ...   ...
#  7788            NaN  2012
#  7789        14985.0  2012
#  7790        14985.0  2012
#  7791        14985.0  2012
#  7792        14985.0  2012
#
#  [7793 rows x 5 columns],
#          UNITID                                         INSTNM  ADM_RATE  \
#  0       100654                       Alabama A & M University    0.8989
#  1       100663            University of Alabama at Birmingham    0.8673
#  2       100690                             Amridge University       NaN
#  3       100706            University of Alabama in Huntsville    0.8062
#  4       100724                       Alabama State University    0.5125
#  ...        ...                                            ...       ...
#  7799  48285703       Georgia Military College-Columbus Campus       NaN
#  7800  48285704       Georgia Military College-Valdosta Campus       NaN
#  7801  48285705  Georgia Military College-Warner Robins Campus       NaN
#  7802  48285706                Georgia Military College-Online       NaN
#  7803  48285707        Georgia Military College-Stone Mountain       NaN
#
#        TUITIONFEE_IN  year
#  0            7182.0  2013
#  1            7206.0  2013
#  2            6870.0  2013
#  3            9192.0  2013
#  4            8720.0  2013
#  ...             ...   ...
#  7799         6276.0  2013
#  7800         5271.0  2013
#  7801         5148.0  2013
#  7802         6900.0  2013
#  7803         5916.0  2013
#
#  [7804 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.5256
#  1       100663                University of Alabama at Birmingham    0.8569
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8203
#  4       100724                           Alabama State University    0.5326
#  ...        ...                                                ...       ...
#  7698  48065701                  Rasmussen College - Overland Park       NaN
#  7699  48154401  National Personal Training Institute of Cleveland       NaN
#  7700  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7701  48400201                        High Desert Medical College       NaN
#  7702  48414501                        Vantage College-San Antonio       NaN
#
#        TUITIONFEE_IN  year
#  0            9096.0  2014
#  1            7510.0  2014
#  2            6900.0  2014
#  3            9158.0  2014
#  4            8720.0  2014
#  ...             ...   ...
#  7698        10764.0  2014
#  7699            NaN  2014
#  7700            NaN  2014
#  7701        29932.0  2014
#  7702            NaN  2014
#
#  [7703 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.6538
#  1       100663                University of Alabama at Birmingham    0.6043
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8120
#  4       100724                           Alabama State University    0.4639
#  ...        ...                                                ...       ...
#  7588  48154401  National Personal Training Institute of Cleveland       NaN
#  7589  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7590  48400201                        High Desert Medical College       NaN
#  7591  48414501                        Vantage College-San Antonio       NaN
#  7592  48621101  American Institute of Pharmaceutical Technolog...       NaN
#
#        TUITIONFEE_IN  year
#  0            9366.0  2015
#  1            7766.0  2015
#  2            6900.0  2015
#  3            9128.0  2015
#  4            8720.0  2015
#  ...             ...   ...
#  7588            NaN  2015
#  7589            NaN  2015
#  7590        31107.0  2015
#  7591            NaN  2015
#  7592            NaN  2015
#
#  [7593 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.8738
#  1       100663                University of Alabama at Birmingham    0.5814
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.7628
#  4       100724                           Alabama State University    0.4590
#  ...        ...                                                ...       ...
#  7170  48305401             Barber School of Pittsburgh - Ambridge       NaN
#  7171  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7172  48400201                        High Desert Medical College       NaN
#  7173  48414501                        Vantage College-San Antonio       NaN
#  7174  48778201                                       BCI - Malden       NaN
#
#        TUITIONFEE_IN  year
#  0            9366.0  2016
#  1            8040.0  2016
#  2            7180.0  2016
#  3            9842.0  2016
#  4            9220.0  2016
#  ...             ...   ...
#  7170            NaN  2016
#  7171            NaN  2016
#  7172            NaN  2016
#  7173            NaN  2016
#  7174            NaN  2016
#
#  [7175 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.9027
#  1       100663                University of Alabama at Birmingham    0.9181
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8123
#  4       100724                           Alabama State University    0.9787
#  ...        ...                                                ...       ...
#  7107  48312404                   Arizona State University at Yuma       NaN
#  7108  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7109  48400201                        High Desert Medical College       NaN
#  7110  48778201                                       BCI - Malden       NaN
#  7111  49005401          Health Career Institute- Lauderdale Lakes       NaN
#
#        TUITIONFEE_IN  year
#  0            9857.0  2017
#  1            8328.0  2017
#  2            6900.0  2017
#  3           10280.0  2017
#  4           11068.0  2017
#  ...             ...   ...
#  7107            NaN  2017
#  7108            NaN  2017
#  7109            NaN  2017
#  7110            NaN  2017
#  7111        22575.0  2017
#
#  [7112 rows x 5 columns]]

# %%
df=pd.concat(df_list)
df.sample(10)
# Out:
#       UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
# 1851  157447            Northern Kentucky University       NaN            NaN
# 4403  363590         Altierus Career College Everett       NaN        13500.0
# 4369  224642               El Paso Community College       NaN            NaN
# 1122  147590  National University of Health Sciences       NaN            NaN
# 4549  261436               Douglas J Aveda Institute       NaN            NaN
# 1569  156903             Daymar College-Paducah Main       NaN            NaN
# 4736  392415                          Fortis College       NaN            NaN
# 1991  168740                      Andrews University    0.4341        15470.0
# 4470  241182    Antilles School of Technical Careers       NaN            NaN
# 1666  164058           Brightwood College-Beltsville       NaN            NaN
#
#       year
# 1851  1996
# 4403  2014
# 4369  1998
# 1122  2013
# 4549  2011
# 1569  2005
# 4736  2014
# 1991  2004
# 4470  2008
# 1666  2012

# %%
df.shape
# Out:
# (154282, 5)

# %%
# <6> 
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)
#(Write code here)

df.head()
df.tail()
df.sample(5)

df.isnull().sum()
#below are the missing data for the columns
# Out:
# UNITID                0
# INSTNM                0
# ADM_RATE         111699
# TUITIONFEE_IN     79394
# year                  0
# dtype: int64

# %%
df.describe()
#statistics showing the count, mean, standard deviation, min, max
# Out:
#              UNITID      ADM_RATE  TUITIONFEE_IN
# count  1.542820e+05  42583.000000   74888.000000
# mean   9.008766e+05      0.694096   11490.999226
# std    4.413740e+06      0.215820    9754.405657
# min    1.006360e+05      0.000000       0.000000
# 25%    1.628300e+05      0.555600    3686.000000
# 50%    2.122760e+05      0.718100    9200.000000
# 75%    4.060600e+05      0.857100   15995.000000
# max    4.900540e+07      1.000000   74787.000000

# %%
# <7>
# the dataframe contains 22 years of data of all U.S. colleges.
# let's just look at UMBC
# filte/query the dataframe to retrieve only rows that belong to UMBC
# save the UMNC data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.
#(Write code here)

umbc=df[df['INSTNM'].str.contains("University of Maryland-Baltimore County")]
umbc
#filtering only UMBC related data
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2083  163268  University of Maryland-Baltimore County       NaN
# 1980  163268  University of Maryland-Baltimore County       NaN
# 1924  163268  University of Maryland-Baltimore County       NaN
# 1915  163268  University of Maryland-Baltimore County       NaN
# 1878  163268  University of Maryland-Baltimore County       NaN
# 1889  163268  University of Maryland-Baltimore County    0.6551
# 1871  163268  University of Maryland-Baltimore County    0.6327
# 1851  163268  University of Maryland-Baltimore County    0.5757
# 1812  163268  University of Maryland-Baltimore County    0.7014
# 1799  163268  University of Maryland-Baltimore County    0.7143
# 1776  163268  University of Maryland-Baltimore County    0.7153
# 1761  163268  University of Maryland-Baltimore County    0.6895
# 1748  163268  University of Maryland-Baltimore County    0.7174
# 1727  163268  University of Maryland-Baltimore County    0.6890
# 1694  163268  University of Maryland-Baltimore County    0.6589
# 1679  163268  University of Maryland-Baltimore County    0.6081
# 1645  163268  University of Maryland-Baltimore County    0.6035
# 1615  163268  University of Maryland-Baltimore County    0.6315
# 1597  163268  University of Maryland-Baltimore County    0.5961
# 1540  163268  University of Maryland-Baltimore County    0.5942
# 1496  163268  University of Maryland-Baltimore County    0.5683
# 1478  163268  University of Maryland-Baltimore County    0.6021
#
#       TUITIONFEE_IN  year
# 2083            NaN  1996
# 1980            NaN  1997
# 1924            NaN  1998
# 1915            NaN  1999
# 1878         5490.0  2000
# 1889         5910.0  2001
# 1871         6362.0  2002
# 1851         7388.0  2003
# 1812         8020.0  2004
# 1799         8520.0  2005
# 1776         8622.0  2006
# 1761         8708.0  2007
# 1748         8780.0  2008
# 1727         8872.0  2009
# 1694         9171.0  2010
# 1679         9467.0  2011
# 1645         9764.0  2012
# 1615        10068.0  2013
# 1597        10384.0  2014
# 1540        11006.0  2015
# 1496        11264.0  2016
# 1478        11518.0  2017

# %%
# <8>
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)
#(Write code here)
umbc.columns
#below are the columns present in umbc dataframe
# Out:
# Index(['UNITID', 'INSTNM', 'ADM_RATE', 'TUITIONFEE_IN', 'year'], dtype='object')

# %%
umbc.head()
#first 5 rows of the dataframe umbc
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2083  163268  University of Maryland-Baltimore County       NaN
# 1980  163268  University of Maryland-Baltimore County       NaN
# 1924  163268  University of Maryland-Baltimore County       NaN
# 1915  163268  University of Maryland-Baltimore County       NaN
# 1878  163268  University of Maryland-Baltimore County       NaN
#
#       TUITIONFEE_IN  year
# 2083            NaN  1996
# 1980            NaN  1997
# 1924            NaN  1998
# 1915            NaN  1999
# 1878         5490.0  2000

# %%
umbc.tail()
#last 5 rows of daatframe umbc
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 1615  163268  University of Maryland-Baltimore County    0.6315
# 1597  163268  University of Maryland-Baltimore County    0.5961
# 1540  163268  University of Maryland-Baltimore County    0.5942
# 1496  163268  University of Maryland-Baltimore County    0.5683
# 1478  163268  University of Maryland-Baltimore County    0.6021
#
#       TUITIONFEE_IN  year
# 1615        10068.0  2013
# 1597        10384.0  2014
# 1540        11006.0  2015
# 1496        11264.0  2016
# 1478        11518.0  2017

# %% [markdown]
# #generate 5 random rows from the dataframe
# umbc.sample(5)

# %%
umbc.isnull().sum()
#below displays the columns with null values
# Out:
# UNITID           0
# INSTNM           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# year             0
# dtype: int64

# %%
#descriptive analytics of the dataframe 
umbc.describe()
# Out:
#          UNITID   ADM_RATE  TUITIONFEE_IN
# count      22.0  17.000000      18.000000
# mean   163268.0   0.644300    8850.777778
# std         0.0   0.052013    1747.028925
# min    163268.0   0.568300    5490.000000
# 25%    163268.0   0.602100    8145.000000
# 50%    163268.0   0.632700    8826.000000
# 75%    163268.0   0.689500    9992.000000
# max    163268.0   0.717400   11518.000000

# %%
# <9> 
# Plot UMBC's in-state tution overtime from 1996 to 2017.

umbc.plot.bar(x="year",y="TUITIONFEE_IN",figsize=(12,8),rot=45)
plt.title("UMBC Tuition")
plt.ylabel("In state tution")
plt.show()

# %%
# <10>
# go back to 5/6/7 and modify the code to look at Johns Hopskins University instead.
# (No code to write here, you just modify the previous cells)
#new dataframe for Johns Hopskins University
jhu=df[df['INSTNM'].str.contains("Johns Hop")]
jhu
# Out:
#       UNITID                    INSTNM  ADM_RATE  TUITIONFEE_IN  year
# 2072  162928  Johns Hopkins University       NaN            NaN  1996
# 1970  162928  Johns Hopkins University       NaN            NaN  1997
# 1915  162928  Johns Hopkins University       NaN            NaN  1998
# 1906  162928  Johns Hopkins University       NaN            NaN  1999
# 1869  162928  Johns Hopkins University       NaN        24930.0  2000
# 1880  162928  Johns Hopkins University    0.3431        26210.0  2001
# 1862  162928  Johns Hopkins University    0.3506        27390.0  2002
# 1843  162928  Johns Hopkins University    0.3060        28730.0  2003
# 1805  162928  Johns Hopkins University    0.3071        30140.0  2004
# 1792  162928  Johns Hopkins University    0.3509        31620.0  2005
# 1769  162928  Johns Hopkins University    0.2792        33900.0  2006
# 1754  162928  Johns Hopkins University    0.2571        35900.0  2007
# 1741  162928  Johns Hopkins University    0.2609        37700.0  2008
# 1720  162928  Johns Hopkins University    0.2782        39150.0  2009
# 1687  162928  Johns Hopkins University    0.2225        40680.0  2010
# 1672  162928  Johns Hopkins University    0.1940        42280.0  2011
# 1638  162928  Johns Hopkins University    0.1843        43390.0  2012
# 1608  162928  Johns Hopkins University    0.1813        45470.0  2013
# 1590  162928  Johns Hopkins University    0.1608        47060.0  2014
# 1533  162928  Johns Hopkins University    0.1412        48710.0  2015
# 1489  162928  Johns Hopkins University    0.1284        50410.0  2016
# 1473  162928  Johns Hopkins University    0.1254        52170.0  2017

# %%
#plotting a bar graph for year vs tuition fees
jhu.plot.bar(x="year",y="TUITIONFEE_IN",figsize=(12,8),rot=45)
plt.title("Johns Hopkins University Tuition")
plt.ylabel("In state tution")
plt.show()

# %%
# <11> 
# Now, we like to compare UMBC and JHU
# filte/query the dataframe to retrieve only rows that belong to UMBC orJHU
# save the UMNC/JHU data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.
#(Write code here)
#umbc data is present in the dataframe umbc
umbc.head()
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2083  163268  University of Maryland-Baltimore County       NaN
# 1980  163268  University of Maryland-Baltimore County       NaN
# 1924  163268  University of Maryland-Baltimore County       NaN
# 1915  163268  University of Maryland-Baltimore County       NaN
# 1878  163268  University of Maryland-Baltimore County       NaN
#
#       TUITIONFEE_IN  year
# 2083            NaN  1996
# 1980            NaN  1997
# 1924            NaN  1998
# 1915            NaN  1999
# 1878         5490.0  2000

# %%
# <12>
# Explore the new dataframe (#of observations, varibles, head, tail, sample, missing values, statistics,etc.)
#(Write code here)

result = pd.concat([umbc, jhu])
result.head(10)
result.tail()
result.sample(10)
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2083  163268  University of Maryland-Baltimore County       NaN
# 1980  163268  University of Maryland-Baltimore County       NaN
# 1924  163268  University of Maryland-Baltimore County       NaN
# 1915  163268  University of Maryland-Baltimore County       NaN
# 1878  163268  University of Maryland-Baltimore County       NaN
# 1889  163268  University of Maryland-Baltimore County    0.6551
# 1871  163268  University of Maryland-Baltimore County    0.6327
# 1851  163268  University of Maryland-Baltimore County    0.5757
# 1812  163268  University of Maryland-Baltimore County    0.7014
# 1799  163268  University of Maryland-Baltimore County    0.7143
#
#       TUITIONFEE_IN  year
# 2083            NaN  1996
# 1980            NaN  1997
# 1924            NaN  1998
# 1915            NaN  1999
# 1878         5490.0  2000
# 1889         5910.0  2001
# 1871         6362.0  2002
# 1851         7388.0  2003
# 1812         8020.0  2004
# 1799         8520.0  2005

# %%
result.isnull().sum()
#printing the null values
# Out:
# UNITID            0
# INSTNM            0
# ADM_RATE         10
# TUITIONFEE_IN     8
# year              0
# dtype: int64

# %%
result.describe()
#descriptive analytics
# Out:
#               UNITID   ADM_RATE  TUITIONFEE_IN
# count      44.000000  34.000000      36.000000
# mean   163098.000000   0.441885   23476.500000
# std       171.965383   0.215650   16078.299307
# min    162928.000000   0.125400    5490.000000
# 25%    162928.000000   0.258050    8849.000000
# 50%    163098.000000   0.459600   18224.000000
# 75%    163268.000000   0.632400   38062.500000
# max    163268.000000   0.717400   52170.000000

# %%
# <13>
# Plot the in-state tuition of both UMBC and JHU over the 22 years on the same plot
# This plot will help us compare the two universities.
#(Write code here)

# %%
com1 = umbc.groupby('year', as_index=False).agg({'TUITIONFEE_IN':'sum'})

# %%
com1_r = com1.rename(columns={"year": "Year","TUITIONFEE_IN":"UMBC_TUITIONFEE_IN"})

# %%
com1_r

#taking the umbc data and using aggregate function 
#with columns year and umbc_tuitionfees
# Out:
#     Year  UMBC_TUITIONFEE_IN
# 0   1996                 0.0
# 1   1997                 0.0
# 2   1998                 0.0
# 3   1999                 0.0
# 4   2000              5490.0
# 5   2001              5910.0
# 6   2002              6362.0
# 7   2003              7388.0
# 8   2004              8020.0
# 9   2005              8520.0
# 10  2006              8622.0
# 11  2007              8708.0
# 12  2008              8780.0
# 13  2009              8872.0
# 14  2010              9171.0
# 15  2011              9467.0
# 16  2012              9764.0
# 17  2013             10068.0
# 18  2014             10384.0
# 19  2015             11006.0
# 20  2016             11264.0
# 21  2017             11518.0

# %%
#taking the umbc data and using aggregate function 
#with columns year and umbc_tuitionfees

com2 = jhu.groupby('year', as_index=False).agg({'TUITIONFEE_IN':'sum'})

# %%
com2_r =com2.rename(columns={"year": "Year","TUITIONFEE_IN":"JHU_TUITIONFEE_IN"})

# %%
com2_r
# Out:
#     Year  JHU_TUITIONFEE_IN
# 0   1996                0.0
# 1   1997                0.0
# 2   1998                0.0
# 3   1999                0.0
# 4   2000            24930.0
# 5   2001            26210.0
# 6   2002            27390.0
# 7   2003            28730.0
# 8   2004            30140.0
# 9   2005            31620.0
# 10  2006            33900.0
# 11  2007            35900.0
# 12  2008            37700.0
# 13  2009            39150.0
# 14  2010            40680.0
# 15  2011            42280.0
# 16  2012            43390.0
# 17  2013            45470.0
# 18  2014            47060.0
# 19  2015            48710.0
# 20  2016            50410.0
# 21  2017            52170.0

# %%
#merging the two datasets for visualization
comb = pd.merge(com1_r,com2_r,on="Year",how="inner")

# %%
comb
# Out:
#     Year  UMBC_TUITIONFEE_IN  JHU_TUITIONFEE_IN
# 0   1996                 0.0                0.0
# 1   1997                 0.0                0.0
# 2   1998                 0.0                0.0
# 3   1999                 0.0                0.0
# 4   2000              5490.0            24930.0
# 5   2001              5910.0            26210.0
# 6   2002              6362.0            27390.0
# 7   2003              7388.0            28730.0
# 8   2004              8020.0            30140.0
# 9   2005              8520.0            31620.0
# 10  2006              8622.0            33900.0
# 11  2007              8708.0            35900.0
# 12  2008              8780.0            37700.0
# 13  2009              8872.0            39150.0
# 14  2010              9171.0            40680.0
# 15  2011              9467.0            42280.0
# 16  2012              9764.0            43390.0
# 17  2013             10068.0            45470.0
# 18  2014             10384.0            47060.0
# 19  2015             11006.0            48710.0
# 20  2016             11264.0            50410.0
# 21  2017             11518.0            52170.0

# %%
#plotting bar graph 
comb.plot(x="Year", y=["UMBC_TUITIONFEE_IN", "JHU_TUITIONFEE_IN"], kind="bar")
plt.title("TUITION FEE COMPARISION")
plt.ylabel("FEES")
# Out:
# Text(0, 0.5, 'FEES')

# %%
# <14> 
# document your observation/conclusion of the plot (use the following Markdown cell)

# %%
#### Based on my observation of the plot,
#### based on the above graph, we can come to conclusion that 
#in year 1996-1999 for the colleges UMBC and JHU the fee value is null
#from the year 2000-2017 the in state tutition fees is increasing for both the universities 
#but we can see that the tutition fee for JHU is more as compared to UMBC

# %%
# The end.
